# %% [markdown]
# <a href="https://colab.research.google.com/github/komolcia/SEA_EU/blob/main/3_pun_translationEN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install openai
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting openai
#   Downloading openai-0.27.4-py3-none-any.whl (70 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.3/70.3 kB 3.2 MB/s eta 0:00:00
# Requirement already satisfied: requests>=2.20 in /usr/local/lib/python3.9/dist-packages (from openai) (2.27.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.9/dist-packages (from openai) (4.65.0)
# Collecting aiohttp
#   Downloading aiohttp-3.8.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 20.7 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests>=2.20->openai) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests>=2.20->openai) (1.26.15)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests>=2.20->openai) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests>=2.20->openai) (2022.12.7)
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.3.3-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (158 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.8/158.8 kB 22.3 MB/s eta 0:00:00
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.8.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (264 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 264.6/264.6 kB 28.5 MB/s eta 0:00:00
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.2/114.2 kB 16.7 MB/s eta 0:00:00
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.9/dist-packages (from aiohttp->openai) (22.2.0)
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Installing collected packages: multidict, frozenlist, async-timeout, yarl, aiosignal, aiohttp, openai
# Successfully installed aiohttp-3.8.4 aiosignal-1.3.1 async-timeout-4.0.2 frozenlist-1.3.3 multidict-6.0.4 openai-0.27.4 yarl-1.8.2

# %%
from sklearn.metrics import accuracy_score, f1_score, precision_score,recall_score
from random import randint
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.naive_bayes import GaussianNB,BernoulliNB,CategoricalNB
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import train_test_split
import numpy as np
import numpy as np
import pandas as pd
import openai
import os
from sklearn.datasets import make_classification
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import confusion_matrix,mean_squared_error, r2_score,classification_report
import pandas as pd
import torch
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import make_pipeline
import re
from mlxtend.plotting import plot_learning_curves
from sklearn.ensemble import RandomForestClassifier
import nltk
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn import linear_model
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import LabelEncoder 
from sklearn.linear_model import RidgeClassifier 
from sklearn.model_selection import train_test_split 
from sklearn.preprocessing import StandardScaler 
from matplotlib import pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
data_train = pd.read_json("joker_translation_EN_FR_train.json")
data_test=pd.read_json("joker_translation_test.json")
data_train
# y=[]
# for x in data_train['wordplay']:
#     if x =="no":
#         y.append(False)
#     else:
#         y.append(True)
# data_train['pun_label']=y
# data_train
# Out:
#         id_en                                            text_en     id_fr  \
# 0     en_1007                      Save the whales, spouted Tom.  fr_11910
# 1     en_1007                      Save the whales, spouted Tom.    fr_712
# 2     en_1007                      Save the whales, spouted Tom.   fr_2853
# 3     en_1007                      Save the whales, spouted Tom.   fr_2924
# 4     en_1007                      Save the whales, spouted Tom.   fr_5994
# ...       ...                                                ...       ...
# 5833   en_965               Sea captains have a lot of latitude.  fr_12401
# 5834   en_968  Last night, I kept dreaming that I had written...   fr_2145
# 5835    en_99        How does a card player party? They shuffle.   fr_3074
# 5836    en_99        How does a card player party? They shuffle.  fr_13150
# 5837    en_99        How does a card player party? They shuffle.   fr_4853
#
#                                                 text_fr
# 0     "Il faut sauver les baleines", jeta Tom avant ...
# 1         "Il faut sauver les baleines", interjeta Tom.
# 2            Moi je sauve les baleines, Tom s’en venta.
# 3     Louis évent-a le projet de sauvetage des balei...
# 4     "Sauvez les baleines", proclama Tom à tout évent.
# ...                                                 ...
# 5833  Les capitaines de navire ont beaucoup de latit...
# 5834  J'ai rêvé que j'étais l'auteur du Seigneur des...
# 5835  Échauffourée au club de bridge : deux personne...
# 5836  Ils font quoi, les joueurs de cartes, au son d...
# 5837  Comment se passe une soirée de joueurs de cart...
#
# [5838 rows x 4 columns]

# %%
#Idk what should we classify we will have true and false values if have many translations and by how many words
da =[]
howmanywords=[]
for y in range(0,len(data_train.index)):
  if (data_train.id_en == data_train.id_en[y]).sum() >1 :
    da.append(True)
  else:
    da.append(False)
  howmanywords.append(len(data_train.text_fr[y].split()))
data_train["hasmany"]=da
data_train["howmany"]=howmanywords

# %%
data_train
# Out:
#         id_en                                            text_en     id_fr  \
# 0     en_1007                      Save the whales, spouted Tom.  fr_11910
# 1     en_1007                      Save the whales, spouted Tom.    fr_712
# 2     en_1007                      Save the whales, spouted Tom.   fr_2853
# 3     en_1007                      Save the whales, spouted Tom.   fr_2924
# 4     en_1007                      Save the whales, spouted Tom.   fr_5994
# ...       ...                                                ...       ...
# 5833   en_965               Sea captains have a lot of latitude.  fr_12401
# 5834   en_968  Last night, I kept dreaming that I had written...   fr_2145
# 5835    en_99        How does a card player party? They shuffle.   fr_3074
# 5836    en_99        How does a card player party? They shuffle.  fr_13150
# 5837    en_99        How does a card player party? They shuffle.   fr_4853
#
#                                                 text_fr  hasmany  howmany
# 0     "Il faut sauver les baleines", jeta Tom avant ...     True       11
# 1         "Il faut sauver les baleines", interjeta Tom.     True        7
# 2            Moi je sauve les baleines, Tom s’en venta.     True        8
# 3     Louis évent-a le projet de sauvetage des balei...     True        8
# 4     "Sauvez les baleines", proclama Tom à tout évent.     True        8
# ...                                                 ...      ...      ...
# 5833  Les capitaines de navire ont beaucoup de latit...     True        8
# 5834  J'ai rêvé que j'étais l'auteur du Seigneur des...    False       12
# 5835  Échauffourée au club de bridge : deux personne...     True       11
# 5836  Ils font quoi, les joueurs de cartes, au son d...     True       17
# 5837  Comment se passe une soirée de joueurs de cart...     True       14
#
# [5838 rows x 6 columns]

# %%
data_test
# Out:
#            id                                               text
# 0        en_8  ''I find you guilty,'' said the judge with con...
# 1        en_9  The student had such a big assignment, he had ...
# 2       en_10               Herbivores come in browns and graze.
# 3       en_11         I'll corroborate that again, Tom reproved.
# 4       en_13  I used to do rock climbing as a youth, but I w...
# ...       ...                                                ...
# 5722  en_9262  I'm thinking of setting up a comedy group to h...
# 5723  en_9263  What did the ocean say to the shore? Nothing, ...
# 5724  en_9264  What did the grape do when he got stepped on? ...
# 5725  en_9265  What is a tornado's favorite game to play? Twi...
# 5726  en_9266  What's the best thing about Switzerland? I don...
#
# [5727 rows x 2 columns]

# %%
from openai.error import RateLimitError
from scipy.sparse import data
import time
openai.api_key = ""
def simpleMyPrompt(prompt,input):

  response = openai.Completion.create(
  model="text-davinci-003",
  prompt=prompt+'Text: '+input+'\nWord:',
  temperature=0.7,
  max_tokens=256,
  top_p=1,
  frequency_penalty=0,
  presence_penalty=0
  )
  return response
prompt =  'Text: Someone once accused me of stealing an old, rare, valuable stamp, and I philately denied it.\n\
Word: Un jour, quelquun ma accusé d avoir volé un timbre de valeur, rare et ancien. Je lui ai dit que, pour porter de telles accusations, il devait être complètement timbré.\n\
\n\
Text: Save the whales, spouted Tom.\n\
Word: "Il faut sauver les baleines", interjeta Tom.\n\
\n'
a=0
data_test1=[]
for i in range(1,4):
  if i*50<data_test["text"].size:
      data_test1.append(data_test['text'].iloc[a:i*40].apply(lambda x:simpleMyPrompt(prompt,x)))
  a=i*50
  time.sleep(30)
  print(i)
  #print(data_test1)
# Out:
# 1
# 2
# 3

# %%
data_test1
# Out:
# [0     {'id': 'cmpl-74xN7olKrGBokNk5NQBR1JLafgj5x', '...
#  1     {'id': 'cmpl-74xN84zfWuWr6Q6rLn1mqDzQ0Ue02', '...
#  2     {'id': 'cmpl-74xN9dCaRzw16czXFeuULPoiPSBS9', '...
#  3     {'id': 'cmpl-74xNEmc8Dz8RBSdlg8KtmDwdr5ufq', '...
#  4     {'id': 'cmpl-74xNFLD4zORNf9OGuhEt3yoKAjuv3', '...
#  5     {'id': 'cmpl-74xNPWtXc2LJFSbpGQIXs4mf8RjFq', '...
#  6     {'id': 'cmpl-74xNQU6m6ngazdF110DFXzrwQxYTL', '...
#  7     {'id': 'cmpl-74xNYx8jkHFN7n2dZ7xlGT49MAQys', '...
#  8     {'id': 'cmpl-74xNZ9tlcvbVQnUzxuyBqHnNXBRdX', '...
#  9     {'id': 'cmpl-74xNb09KGIifMHi3uILajoybK5Y3M', '...
#  10    {'id': 'cmpl-74xNbcvNIIcsazgF8KHzAH2Rqv5D9', '...
#  11    {'id': 'cmpl-74xNcnB9pPLaw5l31xtak1RIJWHrA', '...
#  12    {'id': 'cmpl-74xNdWrkBxUMopSux6oWcUgKksvfC', '...
#  13    {'id': 'cmpl-74xNel133OKKYboKm1PRrW0ciQsC2', '...
#  14    {'id': 'cmpl-74xNffWZRK2e1ww86IqJUZ4As1ZYA', '...
#  15    {'id': 'cmpl-74xNgAUhbdNNTWYMXVnuVphMqq9xD', '...
#  16    {'id': 'cmpl-74xNgWKfej5ZJnodRBaBf7TYniF6t', '...
#  17    {'id': 'cmpl-74xNhsoMhKAEs0vgZvgtc9JXKDzlo', '...
#  18    {'id': 'cmpl-74xNi3p5MTndDXNie4CSvfdaUfTeS', '...
#  19    {'id': 'cmpl-74xNjBGG44SPNCgnND8KZv16PG6Lp', '...
#  20    {'id': 'cmpl-74xNklLBYwNhroOPgKYIcrkAu95iK', '...
#  21    {'id': 'cmpl-74xNlTeDwL6NetCoqv6eWPWKOEnUN', '...
#  22    {'id': 'cmpl-74xNl96vrDWgmytD1IYdhdCah5zG7', '...
#  23    {'id': 'cmpl-74xNmc8059gBvYtK8FfTsxSYdtO8Z', '...
#  24    {'id': 'cmpl-74xNnMrApiYPCY5RyW8AHjvo4hI0Q', '...
#  25    {'id': 'cmpl-74xNoLu5HWj0PqQCbOpxQRq9CIW3M', '...
#  26    {'id': 'cmpl-74xNoiyx2Wwzz5lsM3fnEi1jW4Sfa', '...
#  27    {'id': 'cmpl-74xNpAkM1MMuWIxuGH753oeGuWsRW', '...
#  28    {'id': 'cmpl-74xNqLJHCmJYLkUbEuG1qQM5scaby', '...
#  29    {'id': 'cmpl-74xNqygnx2IBHnkvTODz6Jvu6tCvh', '...
#  30    {'id': 'cmpl-74xNrB5pPXJE8fSRnz6sHrDhYfzZS', '...
#  31    {'id': 'cmpl-74xNsdPuvKn54CslFuw7uy862t7Y2', '...
#  32    {'id': 'cmpl-74xNscZdfIweAza9PxiPru7reoJUZ', '...
#  33    {'id': 'cmpl-74xNtW97A8VKaAKbODcMZFrsSz2x9', '...
#  34    {'id': 'cmpl-74xNviWYFlrWMzTKr6tZggil5TBu3', '...
#  35    {'id': 'cmpl-74xNvXUhdTxrrKyt5Qhuhx3ukdrqb', '...
#  36    {'id': 'cmpl-74xNw7j0irS6SXq1poGXwqkUCaMwP', '...
#  37    {'id': 'cmpl-74xNxZemcDM50s2N7Z5Bung8CjYvE', '...
#  38    {'id': 'cmpl-74xNx3ijz2ugGELjjn1dtu7AsznxM', '...
#  39    {'id': 'cmpl-74xNyqjYaYtiXBe6Zmu5ybDQ1EVy1', '...
#  Name: text, dtype: object,
#  50    {'id': 'cmpl-74xOTwxEHoGijXpiAybwfIye7YB7G', '...
#  51    {'id': 'cmpl-74xOU6ksJ0C8Pjpx0lLf5xLeV68RF', '...
#  52    {'id': 'cmpl-74xOUUvPnVfxH6ILWdKykbaVHRrWF', '...
#  53    {'id': 'cmpl-74xOVgLviRA07HRDY7duoGbLHVRnE', '...
#  54    {'id': 'cmpl-74xOVUjhPHQA0jjVEfXXi4QcjOj2T', '...
#  55    {'id': 'cmpl-74xOWsXhK5UA8DFlExyk5B3t3si9X', '...
#  56    {'id': 'cmpl-74xOXjYgs4dfVKOKKhfz5Jzb5CJGC', '...
#  57    {'id': 'cmpl-74xOYgCfydR8oeM23js0MXsGuwqI4', '...
#  58    {'id': 'cmpl-74xOYaezywN2bHcoFKTGFNsfhJhx8', '...
#  59    {'id': 'cmpl-74xOZ4syxJiCa6rrRESBYJrPN6ChO', '...
#  60    {'id': 'cmpl-74xOahST9RDzQuL380HQLcaynnjV1', '...
#  61    {'id': 'cmpl-74xOaQjjCyAbt74NcWXwyL3G91J2N', '...
#  62    {'id': 'cmpl-74xObMO6rUVSzgrN8CYRuzW2GECLc', '...
#  63    {'id': 'cmpl-74xOc8G0bnfX2suNs3PYMPLyaXwLM', '...
#  64    {'id': 'cmpl-74xOcZOe6v7It3i3neIiVQdBPf6tm', '...
#  65    {'id': 'cmpl-74xOdMzACuUBjiawrFccCfmt5JNuQ', '...
#  66    {'id': 'cmpl-74xOdFGAyi2RR7zVfzu6Xdhu5fIxd', '...
#  67    {'id': 'cmpl-74xOez8eddDgVUVKpkMDovhFqQrh3', '...
#  68    {'id': 'cmpl-74xOfvnJCkWqZINQLbo9utClD74wq', '...
#  69    {'id': 'cmpl-74xOfi9i5akH88080JZKhwneq5chj', '...
#  70    {'id': 'cmpl-74xOgTIlxrPdJF5NyKmItZTHmO1gx', '...
#  71    {'id': 'cmpl-74xOgj360kmMtFosIsjah7c4FbXbh', '...
#  72    {'id': 'cmpl-74xOh6mQpUINcTbtCDU6SrHtLrRDw', '...
#  73    {'id': 'cmpl-74xOifW0blQpJUzL9dsy3LL0GfxcQ', '...
#  74    {'id': 'cmpl-74xOifUNywnpSXX31J12bNYOSmFhe', '...
#  75    {'id': 'cmpl-74xOjZuLxUyrY85kXvsmeKrvN5QkX', '...
#  76    {'id': 'cmpl-74xOkmRrI17AoD2VoDTe9UVukgSJB', '...
#  77    {'id': 'cmpl-74xOkgb7FmyxBwOlKDZXGDq82tWKr', '...
#  78    {'id': 'cmpl-74xOl8AVFEiDO0owdK9eRs8aP52NB', '...
#  79    {'id': 'cmpl-74xOmn90qvwa5sDZA5B8UjgEDjRUu', '...
#  Name: text, dtype: object,
#  100    {'id': 'cmpl-74xPH3sq0qZn57UIKXd8b7YYCYld5', '...
#  101    {'id': 'cmpl-74xPH56DEskpAKdEraPZyWNx0b7kD', '...
#  102    {'id': 'cmpl-74xPIN069WGDgutyn6mfqGr6aedUt', '...
#  103    {'id': 'cmpl-74xPJ8pGMsxbZdf7VGSnhGt1GUxt8', '...
#  104    {'id': 'cmpl-74xPK5veJXyqeUnwYDfz1VOSzQKtS', '...
#  105    {'id': 'cmpl-74xPKOHRHeDXfZJ8bXL4uJpEMwQ8z', '...
#  106    {'id': 'cmpl-74xPLCVDA0R6DuvAj5hZxMAGy7xSb', '...
#  107    {'id': 'cmpl-74xPM5SvubWAszjqrhMDKYqQWzFag', '...
#  108    {'id': 'cmpl-74xPMvX8RKWyT7pL09J7dYrRoc0el', '...
#  109    {'id': 'cmpl-74xPNsZHipm2MOQQAybKRmzc8A2uC', '...
#  110    {'id': 'cmpl-74xPOV6wjyYqYluhOQvARCZvkvLY7', '...
#  111    {'id': 'cmpl-74xPOWDP9PgOAg6hOrKvPJhPevHBD', '...
#  112    {'id': 'cmpl-74xPPLWrcGkMA5a8hmuneJ9r4m8Nv', '...
#  113    {'id': 'cmpl-74xPQeyKqIUNLFJvJWwKX9AXdkTWm', '...
#  114    {'id': 'cmpl-74xPR6TvKbD8iYL8ze8ms692Mb5af', '...
#  115    {'id': 'cmpl-74xPRJAU4fMVlshlO88F0KjiJfNjm', '...
#  116    {'id': 'cmpl-74xPSjk4yfdU5Zw7glOnnHL7QEaEa', '...
#  117    {'id': 'cmpl-74xPSmI0A5ptUlbGv4p7av8DuQ974', '...
#  118    {'id': 'cmpl-74xPTufiogm9qFuZcRailcWFWTBVr', '...
#  119    {'id': 'cmpl-74xPUCuMtDdkQ7LTCh95dzYniGQF5', '...
#  Name: text, dtype: object]

# %%
from functools import reduce
from operator import concat
data_test3 = pd.DataFrame()

data_test3['text_fr_gpt3_my_full']=[smt for sublist in data_test1 for smt in sublist]
print(data_test3['text_fr_gpt3_my_full'])
data_test3['text_fr_gpt3_my']=data_test3['text_fr_gpt3_my_full'].str['choices'].str[0].str['text'].str.strip()
data_test3['text_fr']=data_test3['text_fr_gpt3_my'].str.split('\n')
data_test3['id_en']=data_test['id'].iloc[:90]
data_test3
# Out:
# 0     {'id': 'cmpl-74xN7olKrGBokNk5NQBR1JLafgj5x', '...
# 1     {'id': 'cmpl-74xN84zfWuWr6Q6rLn1mqDzQ0Ue02', '...
# 2     {'id': 'cmpl-74xN9dCaRzw16czXFeuULPoiPSBS9', '...
# 3     {'id': 'cmpl-74xNEmc8Dz8RBSdlg8KtmDwdr5ufq', '...
# 4     {'id': 'cmpl-74xNFLD4zORNf9OGuhEt3yoKAjuv3', '...
#                             ...
# 85    {'id': 'cmpl-74xPRJAU4fMVlshlO88F0KjiJfNjm', '...
# 86    {'id': 'cmpl-74xPSjk4yfdU5Zw7glOnnHL7QEaEa', '...
# 87    {'id': 'cmpl-74xPSmI0A5ptUlbGv4p7av8DuQ974', '...
# 88    {'id': 'cmpl-74xPTufiogm9qFuZcRailcWFWTBVr', '...
# 89    {'id': 'cmpl-74xPUCuMtDdkQ7LTCh95dzYniGQF5', '...
# Name: text_fr_gpt3_my_full, Length: 90, dtype: object
#                                  text_fr_gpt3_my_full  \
# 0   {'id': 'cmpl-74xN7olKrGBokNk5NQBR1JLafgj5x', '...
# 1   {'id': 'cmpl-74xN84zfWuWr6Q6rLn1mqDzQ0Ue02', '...
# 2   {'id': 'cmpl-74xN9dCaRzw16czXFeuULPoiPSBS9', '...
# 3   {'id': 'cmpl-74xNEmc8Dz8RBSdlg8KtmDwdr5ufq', '...
# 4   {'id': 'cmpl-74xNFLD4zORNf9OGuhEt3yoKAjuv3', '...
# ..                                                ...
# 85  {'id': 'cmpl-74xPRJAU4fMVlshlO88F0KjiJfNjm', '...
# 86  {'id': 'cmpl-74xPSjk4yfdU5Zw7glOnnHL7QEaEa', '...
# 87  {'id': 'cmpl-74xPSmI0A5ptUlbGv4p7av8DuQ974', '...
# 88  {'id': 'cmpl-74xPTufiogm9qFuZcRailcWFWTBVr', '...
# 89  {'id': 'cmpl-74xPUCuMtDdkQ7LTCh95dzYniGQF5', '...
#
#                                       text_fr_gpt3_my  \
# 0   ''Je vous déclare coupable'', dit le juge avec...
# 1   L'étudiant avait une telle tâche à accomplir q...
# 2       Les herbivores arrivent en bruns et broutent.
# 3   "Je confirme ça encore une fois, reprit Tom d'...
# 4   Quand j'étais jeune, je pratiquais l'escalade,...
# ..                                                ...
# 85  Elle est devenue une opératrice téléphonique c...
# 86              Les voleurs ont des muscles en acier.
# 87  "Si vous soufflez fort sur la carte, elle révè...
# 88  ''Arrête, cheval ! Arrête !'', s'écria Tom dés...
# 89  Ce fut un jour triste pour la famille des crot...
#
#                                               text_fr   id_en
# 0   [''Je vous déclare coupable'', dit le juge ave...    en_8
# 1   [L'étudiant avait une telle tâche à accomplir ...    en_9
# 2     [Les herbivores arrivent en bruns et broutent.]   en_10
# 3   ["Je confirme ça encore une fois, reprit Tom d...   en_11
# 4   [Quand j'étais jeune, je pratiquais l'escalade...   en_13
# ..                                                ...     ...
# 85  [Elle est devenue une opératrice téléphonique ...  en_205
# 86            [Les voleurs ont des muscles en acier.]  en_208
# 87  ["Si vous soufflez fort sur la carte, elle rév...  en_211
# 88  [''Arrête, cheval ! Arrête !'', s'écria Tom dé...  en_220
# 89  [Ce fut un jour triste pour la famille des cro...  en_222
#
# [90 rows x 4 columns]

# %%
#Idk what should we classify we will have true and false values if have many translations and by how many words
da =[]
howmanywords=[]
for y in range(0,len(data_test3.index)):
  if (data_test3.id_en == data_test3.id_en[y]).sum() >1 :
    da.append(True)
  else:
    da.append(False)
  howmanywords.append(len(data_test3.text_fr_gpt3_my[y].split()))
data_test3["hasmany"]=da
data_test3["howmany"]=howmanywords
data_test3
# Out:
#                                  text_fr_gpt3_my_full  \
# 0   {'id': 'cmpl-74xN7olKrGBokNk5NQBR1JLafgj5x', '...
# 1   {'id': 'cmpl-74xN84zfWuWr6Q6rLn1mqDzQ0Ue02', '...
# 2   {'id': 'cmpl-74xN9dCaRzw16czXFeuULPoiPSBS9', '...
# 3   {'id': 'cmpl-74xNEmc8Dz8RBSdlg8KtmDwdr5ufq', '...
# 4   {'id': 'cmpl-74xNFLD4zORNf9OGuhEt3yoKAjuv3', '...
# ..                                                ...
# 85  {'id': 'cmpl-74xPRJAU4fMVlshlO88F0KjiJfNjm', '...
# 86  {'id': 'cmpl-74xPSjk4yfdU5Zw7glOnnHL7QEaEa', '...
# 87  {'id': 'cmpl-74xPSmI0A5ptUlbGv4p7av8DuQ974', '...
# 88  {'id': 'cmpl-74xPTufiogm9qFuZcRailcWFWTBVr', '...
# 89  {'id': 'cmpl-74xPUCuMtDdkQ7LTCh95dzYniGQF5', '...
#
#                                       text_fr_gpt3_my  \
# 0   ''Je vous déclare coupable'', dit le juge avec...
# 1   L'étudiant avait une telle tâche à accomplir q...
# 2       Les herbivores arrivent en bruns et broutent.
# 3   "Je confirme ça encore une fois, reprit Tom d'...
# 4   Quand j'étais jeune, je pratiquais l'escalade,...
# ..                                                ...
# 85  Elle est devenue une opératrice téléphonique c...
# 86              Les voleurs ont des muscles en acier.
# 87  "Si vous soufflez fort sur la carte, elle révè...
# 88  ''Arrête, cheval ! Arrête !'', s'écria Tom dés...
# 89  Ce fut un jour triste pour la famille des crot...
#
#                                               text_fr   id_en  hasmany  \
# 0   [''Je vous déclare coupable'', dit le juge ave...    en_8    False
# 1   [L'étudiant avait une telle tâche à accomplir ...    en_9    False
# 2     [Les herbivores arrivent en bruns et broutent.]   en_10    False
# 3   ["Je confirme ça encore une fois, reprit Tom d...   en_11    False
# 4   [Quand j'étais jeune, je pratiquais l'escalade...   en_13    False
# ..                                                ...     ...      ...
# 85  [Elle est devenue une opératrice téléphonique ...  en_205    False
# 86            [Les voleurs ont des muscles en acier.]  en_208    False
# 87  ["Si vous soufflez fort sur la carte, elle rév...  en_211    False
# 88  [''Arrête, cheval ! Arrête !'', s'écria Tom dé...  en_220    False
# 89  [Ce fut un jour triste pour la famille des cro...  en_222    False
#
#     howmany
# 0         9
# 1        16
# 2         7
# 3        11
# 4        14
# ..      ...
# 85       12
# 86        7
# 87       13
# 88        8
# 89       22
#
# [90 rows x 6 columns]

# %%
X=data_train["howmany"].values.astype("int").reshape(-1, 1)
y = data_train["hasmany"].values
X_train, X_test1,y_train,y_test1 = train_test_split(X,y,test_size=0.2,random_state=7)
X=data_test3["howmany"].values.astype("int").reshape(-1, 1)
y = data_test3["hasmany"].values 
X_train1, X_test,y_train1,y_test = train_test_split(X,y,test_size=0.9,random_state=7)

#X_train, y_train = train.drop("target"), train["target"]
#X_test, y_test = test.drop("target"), test["target"]

clf=RandomForestClassifier()
clf.fit(X_train, y_train)
pred_labels=clf.predict(X_test)
print("Classes: ",clf.classes_)
score=clf.score(X_test,y_test)
print("\n*--------------------------------------------------*\n")
print("Score: ",score)
print("\n*--------------------------------------------------*\n")
print('Training set score: {:.4f}'.format(clf.score(X_train, y_train)))
print('Test set score: {:.4f}'.format(clf.score(X_test, y_test)))
print("\n*--------------------------------------------------*\n")
print( classification_report(y_test,pred_labels))
print("\n*--------------------------------------------------*\n")
y_pred = clf.predict(X_test)
cm = confusion_matrix(y_test, y_pred, labels=clf.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                              display_labels=clf.classes_)
disp.plot()

plt.show()
# Out:
# Classes:  [False  True]
#
# *--------------------------------------------------*
#
# Score:  0.012345679012345678
#
# *--------------------------------------------------*
#
# Training set score: 0.9334
# Test set score: 0.0123
#
# *--------------------------------------------------*
#
#               precision    recall  f1-score   support
#
#        False       1.00      0.01      0.02        81
#         True       0.00      0.00      0.00         0
#
#     accuracy                           0.01        81
#    macro avg       0.50      0.01      0.01        81
# weighted avg       1.00      0.01      0.02        81
#
#
# *--------------------------------------------------*

# %%
def naive_Bayes(X,y,typ):
    model=typ
    clf=model.fit(X_train,y_train)
    pred_labels=model.predict(X_test)
    print("Classes: ",clf.classes_)
    print("\n*--------------------------------------------------*\n")
    if str(typ)=='GaussianNB()':
        print("Class Priors: ", clf.class_prior_)
    else:
        print("Class Priors: ", clf.class_log_prior_)
    score=model.score(X_test,y_test)
    print("\n*--------------------------------------------------*\n")
    print("Score: ",score)
    print("\n*--------------------------------------------------*\n")
    print('Training set score: {:.4f}'.format(model.score(X_train, y_train)))
    print('Test set score: {:.4f}'.format(model.score(X_test, y_test)))
    print("\n*--------------------------------------------------*\n")
    print( classification_report(y_test,pred_labels))
    print("\n*--------------------------------------------------*\n")
    print( classification_report(y_test,pred_labels))
    print("\n*--------------------------------------------------*\n")
    y_pred = clf.predict(X_test)
    cm = confusion_matrix(y_test, y_pred, labels=clf.classes_)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                              display_labels=clf.classes_)
    disp.plot()

    plt.show()
    return X_train,X_test,y_train,y_test,clf,pred_labels

# %%
naive_Bayes(X,y, GaussianNB())
# Out:
# Classes:  [False  True]
#
# *--------------------------------------------------*
#
# Class Priors:  [0.06745182 0.93254818]
#
# *--------------------------------------------------*
#
# Score:  0.012345679012345678
#
# *--------------------------------------------------*
#
# Training set score: 0.9293
# Test set score: 0.0123
#
# *--------------------------------------------------*
#
#               precision    recall  f1-score   support
#
#        False       1.00      0.01      0.02        81
#         True       0.00      0.00      0.00         0
#
#     accuracy                           0.01        81
#    macro avg       0.50      0.01      0.01        81
# weighted avg       1.00      0.01      0.02        81
#
#
# *--------------------------------------------------*
#
#               precision    recall  f1-score   support
#
#        False       1.00      0.01      0.02        81
#         True       0.00      0.00      0.00         0
#
#     accuracy                           0.01        81
#    macro avg       0.50      0.01      0.01        81
# weighted avg       1.00      0.01      0.02        81
#
#
# *--------------------------------------------------*
# (array([[14],
#         [25],
#         [13],
#         ...,
#         [ 9],
#         [ 9],
#         [24]]),
#  array([[10],
#         [22],
#         [12],
#         [14],
#         [11],
#         [13],
#         [11],
#         [10],
#         [ 9],
#         [ 8],
#         [13],
#         [11],
#         [11],
#         [11],
#         [10],
#         [13],
#         [ 7],
#         [19],
#         [12],
#         [21],
#         [15],
#         [11],
#         [19],
#         [11],
#         [14],
#         [16],
#         [11],
#         [10],
#         [12],
#         [ 9],
#         [12],
#         [38],
#         [22],
#         [11],
#         [10],
#         [ 7],
#         [14],
#         [17],
#         [ 6],
#         [13],
#         [13],
#         [11],
#         [11],
#         [14],
#         [14],
#         [16],
#         [25],
#         [12],
#         [11],
#         [ 7],
#         [12],
#         [12],
#         [14],
#         [14],
#         [11],
#         [15],
#         [ 9],
#         [20],
#         [ 5],
#         [ 8],
#         [ 9],
#         [14],
#         [15],
#         [12],
#         [14],
#         [16],
#         [19],
#         [ 7],
#         [ 6],
#         [18],
#         [11],
#         [17],
#         [ 9],
#         [12],
#         [15],
#         [12],
#         [ 8],
#         [19],
#         [15],
#         [13],
#         [18]]),
#  array([ True,  True,  True, ...,  True,  True,  True]),
#  array([False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False]),
#  GaussianNB(),
#  array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True, False,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True]))

# %%
def generic_fun(X,y,typ):
    model=typ
    clf=model.fit(X_train,y_train)
    score=model.score(X_test,y_test)
    pred_labels=model.predict(X_test)
    print("\n*--------------------------------------------------*\n")
    print("Score: ",score)
    print("\n*--------------------------------------------------*\n")
    print('Training set score: {:.4f}'.format(model.score(X_train, y_train)))
    print('Test set score: {:.4f}'.format(model.score(X_test, y_test)))
    print("\n*--------------------------------------------------*\n")
    print( classification_report(y_test,pred_labels))
    print("\n*--------------------------------------------------*\n")
    y_pred = clf.predict(X_test)
    cm = confusion_matrix(y_test, y_pred, labels=clf.classes_)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                              display_labels=clf.classes_)
      
    disp.plot()

    plt.show()
    return X_train,X_test,y_train,y_test,clf,pred_labels
generic_fun(X,y, RidgeClassifier() )
# Out:
# *--------------------------------------------------*
#
# Score:  0.0
#
# *--------------------------------------------------*
#
# Training set score: 0.9325
# Test set score: 0.0000
#
# *--------------------------------------------------*
#
#               precision    recall  f1-score   support
#
#        False       0.00      0.00      0.00      81.0
#         True       0.00      0.00      0.00       0.0
#
#     accuracy                           0.00      81.0
#    macro avg       0.00      0.00      0.00      81.0
# weighted avg       0.00      0.00      0.00      81.0
#
#
# *--------------------------------------------------*
# (array([[14],
#         [25],
#         [13],
#         ...,
#         [ 9],
#         [ 9],
#         [24]]),
#  array([[10],
#         [22],
#         [12],
#         [14],
#         [11],
#         [13],
#         [11],
#         [10],
#         [ 9],
#         [ 8],
#         [13],
#         [11],
#         [11],
#         [11],
#         [10],
#         [13],
#         [ 7],
#         [19],
#         [12],
#         [21],
#         [15],
#         [11],
#         [19],
#         [11],
#         [14],
#         [16],
#         [11],
#         [10],
#         [12],
#         [ 9],
#         [12],
#         [38],
#         [22],
#         [11],
#         [10],
#         [ 7],
#         [14],
#         [17],
#         [ 6],
#         [13],
#         [13],
#         [11],
#         [11],
#         [14],
#         [14],
#         [16],
#         [25],
#         [12],
#         [11],
#         [ 7],
#         [12],
#         [12],
#         [14],
#         [14],
#         [11],
#         [15],
#         [ 9],
#         [20],
#         [ 5],
#         [ 8],
#         [ 9],
#         [14],
#         [15],
#         [12],
#         [14],
#         [16],
#         [19],
#         [ 7],
#         [ 6],
#         [18],
#         [11],
#         [17],
#         [ 9],
#         [12],
#         [15],
#         [12],
#         [ 8],
#         [19],
#         [15],
#         [13],
#         [18]]),
#  array([ True,  True,  True, ...,  True,  True,  True]),
#  array([False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False]),
#  RidgeClassifier(),
#  array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True]))

# %%
def neural_network(hidden_layer_sizes,max_iter,activation,solver,learning_rate,X,y):
    scaler = StandardScaler()

    scaler.fit(X_train)

    train_data = scaler.transform(X_train)
    test_data = scaler.transform(X_test)
    print(train_data[:3])

    mlp = MLPClassifier(hidden_layer_sizes=hidden_layer_sizes, max_iter=max_iter,
                        activation=activation,
                        solver=solver,
                        learning_rate=learning_rate)

    mlp.fit(train_data, y_train)
    pred_labels=mlp.predict(X_test)
    predictions_train = mlp.predict(train_data)
    predictions_test = mlp.predict(test_data)
    percent = (mlp.score(test_data, y_test))
    print("Percent: ",percent)
    print('Training set score: {:.4f}'.format(mlp.score(train_data, y_train)))
    print('Test set score: {:.4f}'.format(mlp.score(test_data, y_test)))
    print("\n*--------------------------------------------------*\n")
    print( classification_report(y_test,pred_labels))
    print("\n*--------------------------------------------------*\n")
    print( classification_report(y_test,pred_labels))
    print("\n*--------------------------------------------------*\n")
    plot_learning_curves(X_train, y_train, X_test, y_test,mlp)
    y_pred = mlp.predict(X_test)
    cm = confusion_matrix(y_test, y_pred, labels=clf.classes_)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                              display_labels=clf.classes_)
      
    disp.plot()

    plt.show()
    plt.show()
    return ["Neural Network", percent, mlp]
r=neural_network((10, 10),1000,'relu','adam','constant',X,y)
# Out:
# [[ 0.17896946]
#  [ 2.45688348]
#  [-0.02811364]]
# Percent:  0.0
# Training set score: 0.9325
# Test set score: 0.0000
#
# *--------------------------------------------------*
#
#               precision    recall  f1-score   support
#
#        False       0.00      0.00      0.00      81.0
#         True       0.00      0.00      0.00       0.0
#
#     accuracy                           0.00      81.0
#    macro avg       0.00      0.00      0.00      81.0
# weighted avg       0.00      0.00      0.00      81.0
#
#
# *--------------------------------------------------*
#
#               precision    recall  f1-score   support
#
#        False       0.00      0.00      0.00      81.0
#         True       0.00      0.00      0.00       0.0
#
#     accuracy                           0.00      81.0
#    macro avg       0.00      0.00      0.00      81.0
# weighted avg       0.00      0.00      0.00      81.0
#
#
# *--------------------------------------------------*

# %%
pip install fasttext
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: fasttext in /usr/local/lib/python3.9/dist-packages (0.9.2)
# Requirement already satisfied: pybind11>=2.2 in /usr/local/lib/python3.9/dist-packages (from fasttext) (2.10.4)
# Requirement already satisfied: setuptools>=0.7.0 in /usr/local/lib/python3.9/dist-packages (from fasttext) (67.6.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from fasttext) (1.22.4)

# %%
#doesn't work
import fasttext
model = fasttext.train_supervised(input="train.txt")
model.predict("flour")
print(model.test("test.txt") )
text = "coach"
labels, prob = model.predict(text)
print("Label:", labels)
print("Probability:", prob)

# %%
pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers
#   Downloading transformers-4.28.0-py3-none-any.whl (7.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 76.7 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from transformers) (23.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.9/dist-packages (from transformers) (6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from transformers) (3.11.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.9/dist-packages (from transformers) (2022.10.31)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.9/dist-packages (from transformers) (4.65.0)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 97.7 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.9/dist-packages (from transformers) (1.22.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from transformers) (2.27.1)
# Collecting huggingface-hub<1.0,>=0.11.0
#   Downloading huggingface_hub-0.13.4-py3-none-any.whl (200 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.1/200.1 kB 27.3 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub<1.0,>=0.11.0->transformers) (4.5.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (1.26.15)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (3.4)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (2022.12.7)
# Installing collected packages: tokenizers, huggingface-hub, transformers
# Successfully installed huggingface-hub-0.13.4 tokenizers-0.13.3 transformers-4.28.0

# %%
from transformers import AutoTokenizer, BloomForTokenClassification
import torch

tokenizer = AutoTokenizer.from_pretrained("bigscience/bloom-560m")
model = BloomForTokenClassification.from_pretrained("bigscience/bloom-560m")

inputs = tokenizer(
    "HuggingFace is a company based in Paris and New York", add_special_tokens=False, return_tensors="pt"
)

with torch.no_grad():
    logits = model(**inputs).logits

predicted_token_class_ids = logits.argmax(-1)

# Note that tokens are classified rather then input words which means that
# there might be more predicted token classes than words.
# Multiple token classes might account for the same word
predicted_tokens_classes = [model.config.id2label[t.item()] for t in predicted_token_class_ids[0]]

labels = predicted_token_class_ids
loss = model(**inputs, labels=labels).loss
# Out:
# Some weights of BloomForTokenClassification were not initialized from the model checkpoint at bigscience/bloom-560m and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
